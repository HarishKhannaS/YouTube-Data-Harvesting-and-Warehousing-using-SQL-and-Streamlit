# %%
from googleapiclient.discovery import build
import mysql.connector
import pandas as pd
import re
from datetime import datetime
import streamlit as st
from dateutil import parser
import pymysql

# %%
CHANNEL_ID =("UCRz32i7F0hArfqshGThsM8w")

# %%
# API Key connection

def Api_connect():
    Api_Id="AIzaSyC0w8CjdUD9SuS9pwBSgBbF6d_zQxIQw7E"
    api_service_name="youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
request=youtube.channels().list(
                part="snippet,ContentDetails,statistics",
                id="UCRz32i7F0hArfqshGThsM8w"
)
response=request.execute()

# %%
def get_channel_details(c_id):
    response = youtube.channels().list(
                  part="snippet,contentDetails,statistics",
                  id=c_id).execute()
    
    channel_data = []
    for item in response.get("items", []):
               
        published_at = parser.parse(response['items'][0]["snippet"]["publishedAt"]).strftime("%Y-%m-%d %H:%M:%S")
        data=dict(channel_name =response['items'][0]["snippet"]["title"],
                    channel_Id =response['items'][0]["id"],
                    publishe_at =published_at,
                    playlist_id =response['items'][0]["contentDetails"]["relatedPlaylists"]["uploads"],
                    sub_count =response['items'][0]["statistics"]["subscriberCount"],
                    view_Count =response['items'][0]["statistics"]["viewCount"],
                    video_count =response['items'][0]["statistics"]["videoCount"],
                    channel_description =response['items'][0]["snippet"]["description"])
        channel_data.append(data)
    return channel_data

# %%
channel_details = get_channel_details(CHANNEL_ID)

# %%
channel_details
# Out:
# [{'channel_name': 'Madhampatty Rangaraj ',
#   'channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'publishe_at': '2022-09-04 06:56:04',
#   'playlist_id': 'UURz32i7F0hArfqshGThsM8w',
#   'sub_count': '777000',
#   'view_Count': '163121611',
#   'video_count': '112',
#   'channel_description': 'Madhampatty Rangaraj, Chairman, Madhampatty Group of companies | Actor | Social Activist. \n\nRangaraj\'s passion is animation and he studied engineering before working in the food industry for a job. In 2002, he took over his family\'s businesses along with his brother.Rangaraj moved to Bangalore and started a mess. When he returned to Madhampatty, he cooked for small functions. Rangaraj went on to work with film crews and single-handedly providing them with meals. Rangaraj has worked as a caterer for over 500+ weddings including actor Karthi\'s wedding.Madhampatty Thangavelu Hospitality has also catered for events including the 2013 Coimbatore Marathon.Rangaraj is credited for creating the recipe for green guava chutney. \n\nRangaraj made his film debut with the romantic drama Mehandi Circus (2019).In a review of the film by the Deccan Chronicle, the reviewer wrote that "Popular Chef turned hero Madampatti Rangaraj has been aptly cast as the lead protagonist"'}]

# %%
mydb = pymysql.connect(
 host="localhost",
 user="root",
 password="Ayan@2202",
 database="mydatabase_"
 
 )
mycursor = mydb.cursor

# %%
import mysql.connector
import pymysql

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="mydatabase_",
)

print(mydb)
# Out:
# <pymysql.connections.Connection object at 0x000002AC1E06BB80>

# %%
def get_videos_ids(c_id):
    video_ids=[]
    request = youtube.channels().list( id=c_id,part='contentDetails')
    response = request.execute()
    playlist_id =response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    
    response1 = youtube.playlistItems().list(part = 'snippet',
                                                playlistId =playlist_id,
                                                maxResults=50).execute() 
                                                
    for i in range(len(response1['items'])):
        video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])

    return video_ids

# %%
video_ids = get_videos_ids(CHANNEL_ID)

# %%
video_ids
# Out:
# ['4cbpx9gbeps',
#  'BOwsWIuWykY',
#  'ps5YuR9qxbM',
#  'aFCrd3s7fyo',
#  'ffwbS9u-FBY',
#  'tzZljxydIcY',
#  'f993m9EWcyw',
#  'eYBfW-nF3zg',
#  'gwZsgj5rt7I',
#  'pmxDS2xBg1M',
#  'y-ADsmicL0s',
#  'Z7eAwTADhys',
#  'm0z_xKR4TPM',
#  'Y2kwo2vpgt8',
#  'IFk3On0CAkE',
#  'ELyRfk6RJew',
#  'tTj-Wf-8M2U',
#  'nhfsYUudmMU',
#  '69bXr7ZIglo',
#  'ziGJ5daBIrg',
#  'q9BPyKH7wko',
#  '2gSzOYbA5VI',
#  'wZh-L2YIlqU',
#  'fk1OqZ5O-AA',
#  'AKwPb3Jl8VY',
#  '3QDyHOGQ4rA',
#  'hPV3P8B2Gkk',
#  '7KQA1xjvnyk',
#  'qv9Lw_Ag1FQ',
#  'c7uIQ8_K3fo',
#  'LJN_2kPBjrY',
#  'xaYFRTUrt1g',
#  'ogxUO4_Bp1E',
#  'JTkm6I4pYpc',
#  'xbRT3p4MeJg',
#  'ELFLrZCFJ88',
#  'UoC29QYFBl8',
#  'Jxk4Q2xoMkE',
#  'gIKfMC7WDdU',
#  '-2oOGFxG-8o',
#  'Fm2lR2dXHoM',
#  'KFwaUJTQMZI',
#  'oMkwm7RQ6xo',
#  'Un-ictfu1nw',
#  'Ns_v4nvqd1U',
#  'nofPA2TNvGg',
#  'oP-POapsieA',
#  'TdoHKAhndnY',
#  'wecpbivzAwg',
#  '2bZuiYEORYo']

# %%
#convertion of vid_durarion into min and sec.
def duration_to_sec(Vid_Duration):
    match = re.match(r"^PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?$", Vid_Duration)
    if not match:
        return 0
    hours = int(match.group(1) or 0)
    minutes = int(match.group(2) or 0)
    seconds = int(match.group(3) or 0)
    if hours == 0:
        return (f'{minutes}mins : {seconds}sec')
    else:
        return (f'{hours}hrs : {minutes}mins:{seconds}sec')

# %%
def get_video_info(video_ids):
    video_data = []
    for video_id in video_ids:
        request = youtube.videos().list( part = "snippet,ContentDetails,statistics", id = video_id)

        response = request.execute()

        for item in response["items"]:
            Vid_Duration = item['contentDetails']['duration']
            converted_duration = duration_to_sec(Vid_Duration)   # Corrected from ['Vid_Duration']
            published_date = item['snippet']['publishedAt']
            published_date = datetime.strptime(published_date, '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')

            data2 = dict(Channel_Name=item['snippet']['channelTitle'],
                        Channel_Id= item['snippet']['channelId'],
                        Video_Id=item['id'],
                        Vid_Title=item['snippet']['title'],
                        Tags=item['snippet'].get('tags')[0] if item['snippet'].get('tags') else None,
                        Vid_Thumbnail=item['snippet']['thumbnails']['default']['url'],
                        Vid_Description=item['snippet'].get('description'),
                        Vid_Published_Date=published_date,
                        Vid_Duration=converted_duration,
                        Views=item['statistics'].get('viewCount'),
                        likes=item['statistics'].get('likeCount'),
                        Comments=item['statistics'].get('commentCount'),
                        Favourite_count=item['statistics']['favoriteCount'],
                        Definition=item['contentDetails']['definition'],
                        Caption_Status=item['contentDetails']['caption']
                        )
            video_data.append(data2)
    return video_data

# %%
video_details = get_video_info(video_ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '4cbpx9gbeps',
#   'Vid_Title': '#madhampattyrangaraj #madhampatty #cookwithcomaliseason5 #vijaytv',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/4cbpx9gbeps/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-25 10:42:58',
#   'Vid_Duration': '0mins : 27sec',
#   'Views': '1587393',
#   'likes': '70585',
#   'Comments': '177',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'BOwsWIuWykY',
#   'Vid_Title': 'அரிசி பருப்பு சாதம் | Madhampatty Recipe #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/BOwsWIuWykY/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-23 06:24:40',
#   'Vid_Duration': '0mins : 36sec',
#   'Views': '352935',
#   'likes': '11996',
#   'Comments': '88',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'ps5YuR9qxbM',
#   'Vid_Title': 'Kovai Special Arisi Paruppu Sadam | Madhampatty’s Recipe | Madhampatty Rangaraj',
#   'Tags': 'madhampatty rangaraj',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/ps5YuR9qxbM/default.jpg',
#   'Vid_Description': '#madhampattyrangaraj #madhampatty \n\nArisi paruppu sadam is a classic South Indian dish made by cooking rice and lentils together with spices like cumin, mustard seeds, and curry leaves. It\'s nutritious, flavorful, and often served with accompaniments like pickle, papad, or yogurt. The lentils add protein and texture to the rice, making it a wholesome meal on its own or as a side dish.\n\nCoimbatorians love Arisi Paruppu Sadham as much as they love Biriyani. You will definitely love this dish once you taste it. This is such a healthy food option as well.\nAs this one is everyone\'s favorite dish,We serve this dish in our recently opened restaurant, "Kovai Cafe," which is located in California.\n\nWe will see how to prepare this in simple home-style cooking. The ingredients that we need to prepare this dish are: oil, mustard seeds, dry red chillies, curry leaves, green chillies, small onion, turmeric powder, Sambhar powder, salt, grated coconut, garlic, pepper, cumin seeds, and coconut oil.\n \nLet\'s start to prepare this dish. Add oil and wait till the oil is heated. Add mustard seeds to it and let it splutter. Add dry red chillies, curry leaves, and turmeric powder for color. Green chillies, as per your spice preference, Add small onions (this is preferred as it elevates the taste of the dish). We have washed and soaked 1/2 kg of rice and 150 grams of toor dal for this dish.\n \nNow, further saute until the small onion turns golden. Here, add 2 cubed tomatoes and sauté further until the tomatoes turn mushy. Now add 2 teaspoons of sambhar powder and mix well.\n \nIf all the ingredients are ready with you, this dish can be prepared within 10 minutes. This delicious dish goes well with potato and brinjal fry, which can be prepared with very simple and basic ingredients such as Sambhar powder and salt. This dish can also be served with pickles and curd. If my mother makes this dish, it tastes so good that I eat it first without any side- dishes, then I eat it with pickles, then with potato and brinjal fries, and then I eat it twice with curd. Everyone, do try this recipe and let me know.\n \nAnd now that the masala and all the tomatoes are well cooked, we can add salt as per preference and add cups of water. You can see the color; it is bright red. I added more spice because I like my food to be spicy. You can add them according to your preference and spice tolerance level. At this stage, we can add the soaked rice and dal to this and let it boil. We can now close the lid and pressure cook for 3 whistles. Now that it is done, wait for the most delicious dish, Arsiyum Paruppum.\n \nIn this meantime we will make an another outstanding dish, Potato brinjal fry. Take equally cubed potato and brinjal, mustard seeds, curry leaves, dry red chillies and Sambhar powder and Salt.\n \nTake a pan and add oil. This dish is going to be a bit spicy and crunchy, as we are not going to boil and fry anything; we are just going to sauté them all. Once the oil is heated, add mustard seeds and let it splutter. Add dry red chilies and curry leaves, add 2 tablespoons of sambhar powder, and sauté them. Now immediately add potatoes and brinjal to this, and you can see how well the sambhar powder and oil are blended with the ingredients. Now let them cook on a low flame. You can now add the required amount of salt to this and mix them well.\n \nLet them cook until the brinjal shrivels well. As this looks so appealing, I feel like I want to eat it right away while cooking. Let them cook slowly on a low flame. Add a small amount of water and let it roast well.\n \nThe aroma of the rice is great.Now that the third whistle has also come, you can turn off the flame for the rice. Here, the potato and brinjal are also cooked wonderfully. You can even eat these piping hot, sauteed veggies. Make sure you cut the vegetables into cubes.This makes an excellent combination for arisi paruppu sadham and curd rice. You can see how well the brinja ...
#   'Vid_Published_Date': '2024-05-23 05:28:00',
#   'Vid_Duration': '14mins : 49sec',
#   'Views': '1162854',
#   'likes': '23658',
#   'Comments': '1708',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'aFCrd3s7fyo',
#   'Vid_Title': 'Thank you for being my hero, appa." #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/aFCrd3s7fyo/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-22 10:43:04',
#   'Vid_Duration': '0mins : 51sec',
#   'Views': '2304299',
#   'likes': '97597',
#   'Comments': '347',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'ffwbS9u-FBY',
#   'Vid_Title': 'Madhampatty Cloud Kitchen Tour #madhampattyrangaraj #food #madhampatty #cooking #recipe',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/ffwbS9u-FBY/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-20 07:19:40',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '429965',
#   'likes': '17792',
#   'Comments': '72',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'tzZljxydIcY',
#   'Vid_Title': 'Bts photos #cookwithcomaliseason5 #madhampattyrangaraj #cookwithcomali #vijaytv',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/tzZljxydIcY/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-18 02:31:47',
#   'Vid_Duration': '0mins : 37sec',
#   'Views': '146674',
#   'likes': '7538',
#   'Comments': '40',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'f993m9EWcyw',
#   'Vid_Title': 'Madhampatty Kitchen Tour #madhampattyrangaraj #food #madhampatty #cooking #indianfoodrecipe',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/f993m9EWcyw/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-17 05:56:05',
#   'Vid_Duration': '0mins : 24sec',
#   'Views': '856695',
#   'likes': '33798',
#   'Comments': '140',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'eYBfW-nF3zg',
#   'Vid_Title': '#madhampattyrangaraj #food #madhampatty #cooking',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/eYBfW-nF3zg/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-16 06:14:16',
#   'Vid_Duration': '0mins : 45sec',
#   'Views': '250205',
#   'likes': '11059',
#   'Comments': '70',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'gwZsgj5rt7I',
#   'Vid_Title': 'Madhampatty Kitchen Tour |  Madhampatty Rangaraj | Night Lion Cloud Kitchen',
#   'Tags': 'Madhampatty Rangaraj',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/gwZsgj5rt7I/default.jpg',
#   'Vid_Description': "#madhampattyrangaraj #madhampatty #catering \n\nNight Lion by Madhampatty Pakashala | Peelamedu, Coimbatore order food :  \n\nSwiggy : https://www.swiggy.com/direct/brand/377170?source=swiggy-direct&subSource=youtube\n\nZomato : https://link.zomato.com/xqzv/rshare?id=7462115430563e96\n\n\nWhat sets Madhampatty Rangaraj's YouTube channel apart is its commitment to authenticity. Each recipe is rooted in tradition, showcasing the rich culinary heritage of various cultures and regions. Whether you're craving the aromatic flavors of Indian cuisine, the bold spices of Thai cuisine, or the delicate nuances of Italian cuisine, you'll find a recipe that speaks to your taste buds.\n\nFurthermore, Madhampatty Rangaraj's YouTube channel goes beyond just providing recipes. It's a culinary journey that celebrates the joy of cooking and the art of hospitality. With engaging storytelling and insightful commentary, Madhampatty Rangaraj invites viewers to immerse themselves in the cultural significance of each dish, adding an extra layer of meaning to your Cooking.\n\n©️Madhampatty Rangaraj \n\nInstagram : https://www.instagram.com/madhampatty_rangaraj?igsh=aHhnNTJiaHl0aDJ6\n\nFacebook : https://www.facebook.com/Madhampatty?mibextid=opq0tG\n\nX : https://x.com/madhampattyrr?s=21\n\n\n✉️ranga@madhampattygroups.com",
#   'Vid_Published_Date': '2024-05-16 05:23:58',
#   'Vid_Duration': '10mins : 15sec',
#   'Views': '392440',
#   'likes': '5453',
#   'Comments': '345',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'pmxDS2xBg1M',
#   'Vid_Title': 'Here’s a glimpse of Kovai Cafe restaurant SanJose Opening ceremony #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/pmxDS2xBg1M/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-13 05:34:53',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '631317',
#   'likes': '22706',
#   'Comments': '150',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'y-ADsmicL0s',
#   'Vid_Title': 'Special Creamy Curd Rice - #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/y-ADsmicL0s/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-12 06:05:38',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '1752271',
#   'likes': '78881',
#   'Comments': '285',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'Z7eAwTADhys',
#   'Vid_Title': 'Madhampatty’s Recipe #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/Z7eAwTADhys/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-10 05:30:07',
#   'Vid_Duration': '0mins : 58sec',
#   'Views': '763077',
#   'likes': '29641',
#   'Comments': '135',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'm0z_xKR4TPM',
#   'Vid_Title': 'Madhampatty’s Recipe #madhampattyrangaraj #food',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/m0z_xKR4TPM/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-08 05:52:24',
#   'Vid_Duration': '0mins : 25sec',
#   'Views': '1095644',
#   'likes': '37882',
#   'Comments': '112',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'Y2kwo2vpgt8',
#   'Vid_Title': 'Kozhi Vada Satti Soru & Ghee Podi Kozhi | Madhampatty’s Recipe | Madhampatty Rangaraj',
#   'Tags': 'Madhampatty Rangaraj interview',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/Y2kwo2vpgt8/default.jpg',
#   'Vid_Description': "#madhampattyrangaraj #madhampatty #catering \n\nNight Lion by Madhampatty Pakashala | Peelamedu, Coimbatore order food :  \n\nSwiggy : https://www.swiggy.com/direct/brand/377170?source=swiggy-direct&subSource=youtube\n\nZomato : https://link.zomato.com/xqzv/rshare?id=7462115430563e96\n\n\nWhat sets Madhampatty Rangaraj's YouTube channel apart is its commitment to authenticity. Each recipe is rooted in tradition, showcasing the rich culinary heritage of various cultures and regions. Whether you're craving the aromatic flavors of Indian cuisine, the bold spices of Thai cuisine, or the delicate nuances of Italian cuisine, you'll find a recipe that speaks to your taste buds.\n\nFurthermore, Madhampatty Rangaraj's YouTube channel goes beyond just providing recipes. It's a culinary journey that celebrates the joy of cooking and the art of hospitality. With engaging storytelling and insightful commentary, Madhampatty Rangaraj invites viewers to immerse themselves in the cultural significance of each dish, adding an extra layer of meaning to your Cooking.\n\n©️Madhampatty Rangaraj \n\nInstagram : https://www.instagram.com/madhampatty_rangaraj?igsh=aHhnNTJiaHl0aDJ6\n\nFacebook : https://www.facebook.com/Madhampatty?mibextid=opq0tG\n\nX : https://x.com/madhampattyrr?s=21\n\n\n✉️ranga@madhampattygroups.com",
#   'Vid_Published_Date': '2024-05-08 05:30:11',
#   'Vid_Duration': '14mins : 9sec',
#   'Views': '1043632',
#   'likes': '14554',
#   'Comments': '828',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'IFk3On0CAkE',
#   'Vid_Title': 'மாங்காய் ஊறுகாய் & சாம்பரம் - Madhampatty’s Recipe #madhampattyrangaraj  #food',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/IFk3On0CAkE/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-05 06:08:33',
#   'Vid_Duration': '0mins : 45sec',
#   'Views': '2758549',
#   'likes': '104912',
#   'Comments': '289',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'ELyRfk6RJew',
#   'Vid_Title': '#ranveersingh #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/ELyRfk6RJew/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-05-02 11:20:25',
#   'Vid_Duration': '0mins : 29sec',
#   'Views': '832277',
#   'likes': '32820',
#   'Comments': '88',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'tTj-Wf-8M2U',
#   'Vid_Title': 'அவியல் - Madhampatty’s Recipe | #madhampattyrangaraj #food #recipe',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/tTj-Wf-8M2U/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-30 06:47:38',
#   'Vid_Duration': '0mins : 37sec',
#   'Views': '1826046',
#   'likes': '63357',
#   'Comments': None,
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'nhfsYUudmMU',
#   'Vid_Title': 'ஜவ்வரிசி வடை - Making | Madhampatty’s Recipe #madhampattyrangaraj #Madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/nhfsYUudmMU/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-29 07:26:38',
#   'Vid_Duration': '0mins : 55sec',
#   'Views': '2150072',
#   'likes': '86776',
#   'Comments': None,
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '69bXr7ZIglo',
#   'Vid_Title': '#madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/69bXr7ZIglo/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-27 06:12:34',
#   'Vid_Duration': '0mins : 40sec',
#   'Views': '660480',
#   'likes': '26488',
#   'Comments': '116',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'ziGJ5daBIrg',
#   'Vid_Title': 'Making of Kerala Fusion Sadhya | 7000 Guest | Madhampatty Rangaraj',
#   'Tags': 'Cooku with Comali',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/ziGJ5daBIrg/default.jpg',
#   'Vid_Description': "#madhampattyrangaraj #madhampatty #catering \n\nKaripala Biriyani : https://youtu.be/c7uIQ8_K3fo?si=U8bRWk8rzf_ccPg6\n\nKerala Fusion Sadhya Menu | 7000 Guest | Madhampatty’s Grand Wedding | Madhampatty Rangaraj\n\n\nWhat sets Madhampatty Rangaraj's YouTube channel apart is its commitment to authenticity. Each recipe is rooted in tradition, showcasing the rich culinary heritage of various cultures and regions. Whether you're craving the aromatic flavors of Indian cuisine, the bold spices of Thai cuisine, or the delicate nuances of Italian cuisine, you'll find a recipe that speaks to your taste buds.\n\nFurthermore, Madhampatty Rangaraj's YouTube channel goes beyond just providing recipes. It's a culinary journey that celebrates the joy of cooking and the art of hospitality. With engaging storytelling and insightful commentary, Madhampatty Rangaraj invites viewers to immerse themselves in the cultural significance of each dish, adding an extra layer of meaning to your Cooking.\n\n©️Madhampatty Rangaraj \n\nInstagram : https://www.instagram.com/madhampatty_rangaraj?igsh=aHhnNTJiaHl0aDJ6\n\nFacebook : https://www.facebook.com/Madhampatty?mibextid=opq0tG\n\nX : https://x.com/madhampattyrr?s=21\n\n\n✉️ranga@madhampattygroups.com",
#   'Vid_Published_Date': '2024-04-27 06:01:10',
#   'Vid_Duration': '12mins : 25sec',
#   'Views': '352842',
#   'likes': '4561',
#   'Comments': '195',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'q9BPyKH7wko',
#   'Vid_Title': 'Kerala Special Onam Sadhya by #madhampattyrangaraj #wedding #madhampatty #food #indianfoodrecipe',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/q9BPyKH7wko/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-25 11:13:55',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '9258567',
#   'likes': '480443',
#   'Comments': None,
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '2gSzOYbA5VI',
#   'Vid_Title': 'Kerala Special Chakka Pradhaman #madhampattyrangaraj #wedding #madhampatty #keraladish',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/2gSzOYbA5VI/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-21 11:42:38',
#   'Vid_Duration': '0mins : 24sec',
#   'Views': '7903816',
#   'likes': '283311',
#   'Comments': None,
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'wZh-L2YIlqU',
#   'Vid_Title': '#madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/wZh-L2YIlqU/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-11 12:09:34',
#   'Vid_Duration': '0mins : 35sec',
#   'Views': '524064',
#   'likes': '22666',
#   'Comments': '118',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'fk1OqZ5O-AA',
#   'Vid_Title': 'Appa❤️ #madhampatty #Madhampattythangavel #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/fk1OqZ5O-AA/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-11 04:30:14',
#   'Vid_Duration': '0mins : 56sec',
#   'Views': '545701',
#   'likes': '23150',
#   'Comments': '44',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'AKwPb3Jl8VY',
#   'Vid_Title': 'Sree Varalakshmi Mahaal, Salem #madhampattyrangaraj #madhampatty #catering',
#   'Tags': 'Madhampatty Rangaraj',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/AKwPb3Jl8VY/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-09 10:10:52',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '629709',
#   'likes': '28767',
#   'Comments': '105',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '3QDyHOGQ4rA',
#   'Vid_Title': 'Sangamitra Convention Center, #pondicherry #madhampattyrangaraj #madhampatty #catering',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/3QDyHOGQ4rA/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-04 13:15:54',
#   'Vid_Duration': '0mins : 31sec',
#   'Views': '1299694',
#   'likes': '43899',
#   'Comments': '115',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'hPV3P8B2Gkk',
#   'Vid_Title': 'தம்பி❤️ #madhampattyrangaraj #madhampatty #catering #Madhampattykrishnakumar',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/hPV3P8B2Gkk/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-04 09:53:45',
#   'Vid_Duration': '0mins : 28sec',
#   'Views': '1637706',
#   'likes': '80706',
#   'Comments': '236',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '7KQA1xjvnyk',
#   'Vid_Title': '#drpalmanickam #palmanickam #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/7KQA1xjvnyk/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-04-03 08:26:35',
#   'Vid_Duration': '0mins : 49sec',
#   'Views': '436242',
#   'likes': '23998',
#   'Comments': '103',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'qv9Lw_Ag1FQ',
#   'Vid_Title': '#madhampattyrangaraj #madhampatty #madhampattyrangarajrecipe',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/qv9Lw_Ag1FQ/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-29 05:28:30',
#   'Vid_Duration': '0mins : 35sec',
#   'Views': '4504130',
#   'likes': '170725',
#   'Comments': '261',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'c7uIQ8_K3fo',
#   'Vid_Title': 'Kalyana Veetu Ambur Style Karipala Biryani | Madhampatty’s Recipe | Madhampatty Rangaraj',
#   'Tags': 'Madhampatty Rangaraj',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/c7uIQ8_K3fo/default.jpg',
#   'Vid_Description': "#madhampattyrangaraj #madhampatty #catering \n\nAuthentic Ambur Karipala Biryani Recipe: A Flavorful Journey into South Indian Cuisine\n\n\nWhat sets Madhampatty Rangaraj's YouTube channel apart is its commitment to authenticity. Each recipe is rooted in tradition, showcasing the rich culinary heritage of various cultures and regions. Whether you're craving the aromatic flavors of Indian cuisine, the bold spices of Thai cuisine, or the delicate nuances of Italian cuisine, you'll find a recipe that speaks to your taste buds.\n\nFurthermore, Madhampatty Rangaraj's YouTube channel goes beyond just providing recipes. It's a culinary journey that celebrates the joy of cooking and the art of hospitality. With engaging storytelling and insightful commentary, Madhampatty Rangaraj invites viewers to immerse themselves in the cultural significance of each dish, adding an extra layer of meaning to your Cooking.\n\n©️Madhampatty Rangaraj \n\nInstagram : https://www.instagram.com/madhampatty_rangaraj?igsh=aHhnNTJiaHl0aDJ6\n\nFacebook : https://www.facebook.com/Madhampatty?mibextid=opq0tG\n\nX : https://x.com/madhampattyrr?s=21\n\n\n✉️ranga@madhampattygroups.com",
#   'Vid_Published_Date': '2024-03-29 04:36:13',
#   'Vid_Duration': '10mins : 7sec',
#   'Views': '1416493',
#   'likes': '15890',
#   'Comments': '504',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'LJN_2kPBjrY',
#   'Vid_Title': 'I take this opportunity to thank all lovable MILLION Hearts 💕 #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/LJN_2kPBjrY/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-28 10:46:58',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '554793',
#   'likes': '28642',
#   'Comments': '125',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'xaYFRTUrt1g',
#   'Vid_Title': '#madhampattyrangaraj #traditionallove',
#   'Tags': 'Madhampatty Rangaraj',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/xaYFRTUrt1g/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-26 12:30:41',
#   'Vid_Duration': '0mins : 16sec',
#   'Views': '246360',
#   'likes': '13746',
#   'Comments': '96',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'ogxUO4_Bp1E',
#   'Vid_Title': 'Opportunity is everywhere. The key is to develop the vision to see it.  #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/ogxUO4_Bp1E/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-25 11:30:32',
#   'Vid_Duration': '0mins : 53sec',
#   'Views': '351226',
#   'likes': '19211',
#   'Comments': '132',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'JTkm6I4pYpc',
#   'Vid_Title': '#madhampattyrangaraj #Gym',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/JTkm6I4pYpc/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-23 10:48:21',
#   'Vid_Duration': '0mins : 44sec',
#   'Views': '1140375',
#   'likes': '58133',
#   'Comments': '279',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'xbRT3p4MeJg',
#   'Vid_Title': 'If u want to feel the divine search in yourself ❤️ #madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/xbRT3p4MeJg/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-22 04:30:30',
#   'Vid_Duration': '0mins : 38sec',
#   'Views': '285282',
#   'likes': '15840',
#   'Comments': '61',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'ELFLrZCFJ88',
#   'Vid_Title': '#madhampattyrangaraj #madhampatty',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/ELFLrZCFJ88/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-21 08:39:34',
#   'Vid_Duration': '0mins : 32sec',
#   'Views': '417722',
#   'likes': '25594',
#   'Comments': '144',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'UoC29QYFBl8',
#   'Vid_Title': 'Here’s a Making Glimpse of Cook With Comali Promo!  #madhampattyrangaraj #cookwithcomali',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/UoC29QYFBl8/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-20 12:15:03',
#   'Vid_Duration': '1mins : 1sec',
#   'Views': '596205',
#   'likes': '35580',
#   'Comments': '132',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'Jxk4Q2xoMkE',
#   'Vid_Title': 'With your sparkling smile you make your life and others life a garden.❤️ #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/Jxk4Q2xoMkE/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-20 07:42:17',
#   'Vid_Duration': '0mins : 26sec',
#   'Views': '713360',
#   'likes': '36865',
#   'Comments': '252',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'gIKfMC7WDdU',
#   'Vid_Title': '#cookwithcomali #madhampattyrangaraj Thanks for all your support and love ❤️',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/gIKfMC7WDdU/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-19 11:33:45',
#   'Vid_Duration': '0mins : 25sec',
#   'Views': '159740',
#   'likes': '12336',
#   'Comments': '116',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '-2oOGFxG-8o',
#   'Vid_Title': 'The Plan Behind Mass Food Production | Chennai Marathon 2024  #madhampattyrangaraj',
#   'Tags': 'Cook with comali',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/-2oOGFxG-8o/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-19 05:58:32',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '131248',
#   'likes': '5294',
#   'Comments': '20',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'Fm2lR2dXHoM',
#   'Vid_Title': 'The Plan Behind Mass Food Production | Chennai Marathon 2024 |  Madhampatty Rangaraj',
#   'Tags': 'Madhampatty Rangaraj',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/Fm2lR2dXHoM/default.jpg',
#   'Vid_Description': "#madhampattyrangaraj #madhampatty #catering \n\nThe Culinary Logistics of Chennai Marathon: A Gastronomic Spectacle\n\nIntroduction:\nThe Chennai Marathon stands as a testament to human endurance, community spirit, and health consciousness. Behind this remarkable event lies a lesser-known but equally crucial aspect: food production and distribution. As thousands of participants traverse the city streets, replenishing their energy becomes paramount. This essay delves into the intricate logistics of food production for the Chennai Marathon, highlighting the meticulous planning and execution required to satisfy the appetites of both runners and spectators.\n\nPreparation and Planning:\nMonths before the marathon, meticulous planning commences to ensure a seamless food experience for participants. Event organizers collaborate with local vendors, caterers, and food suppliers to curate a diverse menu that caters to varying dietary preferences and requirements. From carbohydrates to proteins, fruits to energy bars, the menu is crafted to provide runners with the necessary nutrients to fuel their journey.\n\nFood Production:\nOn the day of the marathon, the culinary extravaganza begins before dawn breaks. Teams of chefs and kitchen staff work tirelessly to prepare massive quantities of food. Kitchens buzz with activity as ingredients are chopped, cooked, and assembled into nutritious meals. Hygiene and food safety protocols are strictly adhered to, ensuring the health and well-being of all participants.\n\nDistribution and Logistics:\nAs the sun rises, the focus shifts to distribution and logistics. Stations are strategically set up along the marathon route, manned by volunteers ready to serve hungry runners. Trucks loaded with food supplies navigate the bustling streets of Chennai, ensuring timely replenishment of supplies at each station. Communication channels remain open and efficient, allowing for quick adjustments in case of unforeseen circumstances.\n\nSustainability and Waste Management:\nIn recent years, there has been a growing emphasis on sustainability and waste management in event planning. The Chennai Marathon is no exception. Efforts are made to minimize food waste through careful portion control and donation of surplus food to local charities. Biodegradable packaging and utensils are used wherever possible, reducing the event's environmental footprint.\n\nCommunity Engagement:\nThe Chennai Marathon is not just a sporting event; it's a celebration of community spirit. Food plays a vital role in fostering this sense of camaraderie. Spectators line the streets, cheering on runners while enjoying delicious snacks and refreshments. Food stalls offering local delicacies further enhance the festive atmosphere, providing a culinary journey through Chennai's rich gastronomic heritage.\n\nThe culinary logistics of the Chennai Marathon are a testament to the power of collaboration, efficiency, and innovation. Behind the scenes, a dedicated team works tirelessly to ensure that participants and spectators alike are nourished and energized throughout the event. As runners cross the finish line, their sense of accomplishment is matched only by the satisfaction of a well-deserved meal, marking the culmination of a gastronomic spectacle unlike any other.\n\n©️Madhampatty Rangaraj \n\nInstagram : https://www.instagram.com/madhampatty_rangaraj?igsh=aHhnNTJiaHl0aDJ6\n\nFacebook : https://www.facebook.com/Madhampatty?mibextid=opq0tG\n\nX : https://x.com/madhampattyrr?s=21\n\n\n✉️ranga@madhampattygroups.com",
#   'Vid_Published_Date': '2024-03-15 14:16:34',
#   'Vid_Duration': '8mins : 10sec',
#   'Views': '126944',
#   'likes': '1434',
#   'Comments': '84',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'KFwaUJTQMZI',
#   'Vid_Title': '#madhampattyrangaraj',
#   'Tags': 'Cook with comali',
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/KFwaUJTQMZI/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-15 05:52:38',
#   'Vid_Duration': '0mins : 29sec',
#   'Views': '255698',
#   'likes': '13368',
#   'Comments': '76',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'oMkwm7RQ6xo',
#   'Vid_Title': 'Create your Own Path- #madhampattyrangaraj #catering',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/oMkwm7RQ6xo/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-13 10:47:21',
#   'Vid_Duration': '0mins : 34sec',
#   'Views': '335517',
#   'likes': '20438',
#   'Comments': '81',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'Un-ictfu1nw',
#   'Vid_Title': '#youtubecreatorawards #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/Un-ictfu1nw/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-11 14:00:06',
#   'Vid_Duration': '0mins : 54sec',
#   'Views': '2792955',
#   'likes': '165241',
#   'Comments': '1776',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'Ns_v4nvqd1U',
#   'Vid_Title': 'Madhampatty to Malaysia #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/Ns_v4nvqd1U/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-11 06:23:28',
#   'Vid_Duration': '0mins : 59sec',
#   'Views': '318175',
#   'likes': '14826',
#   'Comments': '65',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'nofPA2TNvGg',
#   'Vid_Title': 'Art of Medu Vada #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/nofPA2TNvGg/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-10 05:21:57',
#   'Vid_Duration': '0mins : 38sec',
#   'Views': '224866',
#   'likes': '9123',
#   'Comments': '63',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'oP-POapsieA',
#   'Vid_Title': '#madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/oP-POapsieA/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-09 05:43:22',
#   'Vid_Duration': '0mins : 23sec',
#   'Views': '405241',
#   'likes': '29421',
#   'Comments': '154',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'TdoHKAhndnY',
#   'Vid_Title': 'அக்கினிச் சிறகே… எழுந்து வா… உலகை அசைப்போம்… உயர்ந்து வா…!  Happy Women’s Day #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/TdoHKAhndnY/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-08 05:30:07',
#   'Vid_Duration': '1mins : 0sec',
#   'Views': '718243',
#   'likes': '37279',
#   'Comments': '188',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': 'wecpbivzAwg',
#   'Vid_Title': '#madhampatty Feast #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/wecpbivzAwg/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-07 11:44:55',
#   'Vid_Duration': '0mins : 16sec',
#   'Views': '1944053',
#   'likes': '66488',
#   'Comments': '188',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Madhampatty Rangaraj ',
#   'Channel_Id': 'UCRz32i7F0hArfqshGThsM8w',
#   'Video_Id': '2bZuiYEORYo',
#   'Vid_Title': 'Create like a god, command like a king, work like a slave! #madhampattyrangaraj',
#   'Tags': None,
#   'Vid_Thumbnail': 'https://i.ytimg.com/vi/2bZuiYEORYo/default.jpg',
#   'Vid_Description': '',
#   'Vid_Published_Date': '2024-03-06 10:00:44',
#   'Vid_Duration': '0mins : 54sec',
#   'Views': '283645',
#   'likes': '14575',
#   'Comments': '92',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
# get comment information
def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request = youtube.commentThreads().list( part="snippet", videoId=video_id, maxResults=100)
               
            response = request.execute()

            for item in response['items']:
                Comment_Published = datetime.strptime(item['snippet']['topLevelComment']['snippet'].get('publishedAt'), "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d %H:%M:%S")
                data3=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=Comment_Published)
                
                Comment_data.append(data3)
    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(video_ids)

# %%
len(comment_details)
# Out:
# 1428

# %%
import mysql.connector
import pymysql

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="project",
)

# %%
# CHANNELS TABLE CREATION AND DETAILS INSERTING INTO MYSQL
def channels_table():
   mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="project",
)
   
cursor = mydb.cursor()


try:
    create_query='''create table if not exists channels(channel_name varchar(100),
                                                        channel_Id varchar(100) primary key,
                                                        publishe_at varchar(100),
                                                        sub_count bigint,
                                                        view_Count bigint,
                                                        video_count int,
                                                        channel_description text,
                                                        playlist_id varchar(100))'''
    cursor.execute(create_query)
    mydb.commit()
except:
    print("channels table already created")

# Fetch channel details
channel_details = get_channel_details(CHANNEL_ID)

# Convert the list of dictionaries to a DataFrame
df1 = pd.DataFrame(channel_details)

for index,row in df1.iterrows():
        insert_query='''insert into channels(channel_name,
                                            channel_Id,
                                            publishe_at,
                                            sub_count,
                                            view_Count,
                                            video_count,
                                            channel_description,
                                            playlist_id)
                                            
                                        values(%s,%s,%s,%s,%s,%s,%s,%s)'''
values=(row['channel_name'],row['channel_Id'],row['publishe_at'],row['sub_count'],row['view_Count'],
        row['video_count'],row['channel_description'],row['playlist_id'])
try:
        cursor.execute(insert_query,values)
        mydb.commit()
except:
        print("channels values are already inserted")

# %%
def videos_table():
  mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="project",
)
cursor = mydb.cursor()


create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                channel_Id varchar(100),
                                                Video_Id varchar(100) primary key,
                                                Vid_Title varchar(150),
                                                Tags text,
                                                Vid_Thumbnail varchar(200),
                                                Vid_Description text,
                                                Vid_Published_Date datetime,
                                                Vid_Duration varchar(250),
                                                Views bigint,
                                                likes bigint,
                                                Comments int,
                                                Favourite_count int,
                                                Definition varchar(10),
                                                Caption_Status varchar(50))'''
cursor.execute(create_query)
mydb.commit()

# Fetch video details
#vi_2
video_ids = get_videos_ids(CHANNEL_ID)
video_details = get_video_info(video_ids)
df2 = pd.DataFrame(video_details)

#inserting of video details and channel table.
# vi_3


for index,row in df2.iterrows():

        insert_query='''insert into videos(Channel_Name,
                                        Channel_Id,
                                        Video_Id,
                                        Vid_Title,
                                        Tags,
                                        Vid_Thumbnail,
                                        Vid_Description,
                                        Vid_Published_Date,
                                        Vid_Duration,
                                        Views,
                                        likes,
                                        Comments,
                                        Favourite_count,
                                        Definition,
                                        Caption_Status)
                                        
                                                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],row['Channel_Id'],row['Video_Id'],row['Vid_Title'],row['Tags'],
        row['Vid_Thumbnail'],row['Vid_Description'],row['Vid_Published_Date'],row['Vid_Duration'],row['Views'],
        row['likes'],row['Comments'],row['Favourite_count'],row['Definition'],row['Caption_Status'])
        
        try:
            cursor.execute(insert_query,values)
            mydb.commit()
        except:
            print("videos values are already inserted")

# %%
def comments_table():
    mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="project",
)
cursor = mydb.cursor()

create_query = '''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                    Video_Id varchar(50),
                                                    Comment_Text text,
                                                    Comment_Author varchar(200),
                                                    Comment_Published timestamp)'''
cursor.execute(create_query)
mydb.commit()

# comment details and data frame conversion.
video_ids = get_videos_ids(CHANNEL_ID)
comment_details=get_comment_info(video_ids) 
for i in range(len(["comment_details"])):
    # data_frame
    df3 = pd.DataFrame(comment_details)


# insert query for comment details in mysql
for index, row in df3.iterrows():
    
    insert_query = '''insert into comments(Comment_Id,
                                            Video_Id,
                                            Comment_Text,
                                            Comment_Author,
                                            Comment_Published)
                                            
                                        values(%s,%s,%s,%s,%s)'''
    values = (row['Comment_Id'], row['Video_Id'], row['Comment_Text'], row['Comment_Author'],row['Comment_Published'])
    try:
            cursor.execute(insert_query, values)
            mydb.commit()
    except:
        print("comments values are already inserted")

# %%
channel_id=CHANNEL_ID

# %%
channel_id
# Out:
# 'UCRz32i7F0hArfqshGThsM8w'

# %%
def tables(channel_id):
    # Set the global CHANNEL_ID variable to the provided channel_id
    global CHANNEL_ID
    CHANNEL_ID = channel_id
    channels_table()
    videos_table()
    comments_table()

    return "tables created successfully"

# %%
Tables=tables(channel_id)

# %%
Tables
# Out:
# 'tables created successfully'

# %%
mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="project",
)

# %%
def show_channels_table(channel_id):
# Fetch channel details
    channel_details = get_channel_details(channel_id)

    # Convert the list of dictionaries to a DataFrame
    df1 = st.dataframe(channel_details)
    return df1

# %%
df1
# Out:
#             channel_name                channel_Id          publishe_at  \
# 0  Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  2022-09-04 06:56:04
#
#                 playlist_id sub_count view_Count video_count  \
# 0  UURz32i7F0hArfqshGThsM8w    777000  163121611         112
#
#                                  channel_description
# 0  Madhampatty Rangaraj, Chairman, Madhampatty Gr...

# %%
def show_videos_table(channel_id):   
    # Fetch video details
    #vi_2
    video_ids = get_videos_ids(channel_id)
    video_details = get_video_info(video_ids)
    df2 = st.dataframe(video_details)
    return df2

# %%
df2
# Out:
#              Channel_Name                Channel_Id     Video_Id  \
# 0   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  4cbpx9gbeps
# 1   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  BOwsWIuWykY
# 2   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  ps5YuR9qxbM
# 3   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  aFCrd3s7fyo
# 4   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  ffwbS9u-FBY
# 5   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  tzZljxydIcY
# 6   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w  f993m9EWcyw
# 7   Madhampatty Rangaraj   UCRz32i7F0hArfqshGThsM8w
# 14   0mins : 45sec  2758549  104912      289               0         hd
# 15   0mins : 29sec   832277   32820       88               0         hd
# 16   0mins : 37sec  1826046   63358     None               0         hd
# 17   0mins : 55sec  2150072   86776     None               0         hd
# 18   0mins : 40sec   660480   26488      116               0         hd
# 19  12mins : 25sec   352842    4561      195               0         hd
# 20    1mins : 0sec  9258567  480443     None               0         hd
# 21   0mins : 24sec  7903816  283311     None               0         hd
# 22   0mins : 35sec   524064   22666      118               0         hd
# 23   0mins : 56sec   545701   23150       44               0         hd
# 24    1mins : 0sec   629709   28767      105               0         hd
# 25   0mins : 31sec  1299694   43899      115               0         hd
# 26   0mins : 28sec  1637823   80706      236               0         hd
# 27   0mins : 49sec   436242   23998      103               0         hd
# 28   0mins : 35sec  4504130  170725      261               0         hd
# 29   10mins : 7sec  1416493   15890      504               0         hd
# 30    1mins : 0sec   554793   28642      125               0         hd
# 31   0mins : 16sec   246360   13746       96               0         hd
# 32   0mins : 53sec   351226   19211      132               0         hd
# 33   0mins : 44sec  1140375   58133      279               0         hd
# 34   0mins : 38sec   285282   15841       61               0         hd
# 35   0mins : 32sec   417722   25594      144               0         hd
# 36    1mins : 1sec   596205   35580      132               0         hd
# 37   0mins : 26sec   713360   36865      252               0         hd
# 38   0mins : 25sec   159740   12336      116               0         hd
# 39    1mins : 0sec   131248    5294       20               0         hd
# 40   8mins : 10sec   126944    1434       84               0         hd
# 41   0mins : 29sec   255698   13368       76               0         hd
# 42   0mins : 34sec   335517   20438       81               0         hd
# 43   0mins : 54sec  2792955  165241     1776               0         hd
# 44   0mins : 59sec   318175   14827       65               0         hd
# 45   0mins : 38sec   224866    9123       63               0         hd
# 46   0mins : 23sec   405241   29421      154               0         hd
# 47    1mins : 0sec   718243   37279      188               0         hd
# 48   0mins : 16sec  1944053   66488      188               0         hd
# 49   0mins : 54sec   283645   14575       92               0         hd
#
#    Caption_Status
# 0           false
# 1           false
# 2           false
# 3           false
# 4           false
# 5           false
# 6           false
# 7           false
# 8           false
# 9           false
# 10          false
# 11          false
# 12          false
# 13          false
# 14          false
# 15          false
# 16          false
# 17          false
# 18          false
# 19          false
# 20          false
# 21          false
# 22          false
# 23          false
# 24          false
# 25          false
# 26          false
# 27          false
# 28          false
# 29          false
# 30          false
# 31          false
# 32          false
# 33          false
# 34          false
# 35          false
# 36          false
# 37          false
# 38          false
# 39          false
# 40          false
# 41          false
# 42          false
# 43          false
# 44          false
# 45          false
# 46          false
# 47          false
# 48          false
# 49          false

# %%
def show_comments_table(channel_id):

# comment details and data frame conversion.
    video_ids = get_videos_ids(channel_id)
    comment_details=get_comment_info(video_ids) 
    for i in range(len(["comment_details"])):
        # data_frame
        df3 = st.dataframe(comment_details)

    return df2

# %%
df3
# Out:
#                       Comment_Id     Video_Id  \
# 0     Ugzor-1ZKTYI16stkWJ4AaABAg  4cbpx9gbeps
# 1     Ugy5V5mgLZBXHrIa9Sp4AaABAg  4cbpx9gbeps
# 2     UgwvCY6F9DgATEJ2HOd4AaABAg  4cbpx9gbeps
# 3     UgwVi7Y-dwh7jhJM3TN4AaABAg  4cbpx9gbeps
# 4     UgxWPcqDXVR0k5fXh7x4AaABAg  4cbpx9gbeps
# ...                          ...          ...
# 1423  UgxJ9KFBcA9GbnhmCK54AaABAg  ELyRfk6RJew
# 1424  UgzmzTiHtR_qR8_fMOp4AaABAg  ELyRfk6RJew
# 1425  UgxEKMjNVApWsyYsIYV4AaABAg  ELyRfk6RJew
# 1426  Ugxo91pDKWPvbCDjo_d4AaABAg  ELyRfk6RJew
# 1427  Ugx-DuLrGu40g8Voevl4AaABAg  ELyRfk6RJew
#
#                                            Comment_Text        Comment_Author  \
# 0     Over scene ah irukae orunaal ivan catering sap...        @devasurya5198
# 1                                              Super❤❤❤  @senthilmuruganp7486
# 2                                  Such a handsome chef              @siv5555
# 3               Ungala pakkumpothu perumaiya irukku sir              @Srirasi
# 4     Resuming of watching cwc only because of you s...      @user-jf7jp8lp5i
# ...                                                 ...                   ...
# 1423                                         Good huMAN      @mathuraasai7529
# 1424                    What a powerful man 🎉🎉bro u r❤❤   @meenakathirvel1251
# 1425                       A big fan of you Rangaraj ❤❤         @dhanudmd1983
# 1426                                 Super sir ♥️❤❤❤❤❤❤      @user-of5yx2dx2e
# 1427                  The man of quality = Rangaraj sir       @jothisorna3359
#
#         Comment_Published
# 0     2024-05-28 14:48:47
# 1     2024-05-28 14:47:36
# 2     2024-05-28 14:42:04
# 3     2024-05-28 11:01:19
# 4     2024-05-28 09:05:30
# ...                   ...
# 1423  2024-05-02 12:21:57
# 1424  2024-05-02 11:55:36
# 1425  2024-05-02 11:43:45
# 1426  2024-05-02 11:32:03
# 1427  2024-05-02 11:27:35
#
# [1428 rows x 5 columns]

# %%
with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WARESTING]")
    st.header("Skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data Collection")
    st.caption("API Integration")

    channel_id = st.text_input("Enter the channel ID")

    if st.button("Collect Data"):
        # Fetch channel details
        channel_details = get_channel_details(channel_id)
        video_ids = get_videos_ids(channel_id)  
        video_details = get_video_info(video_ids)
        comment_details=get_comment_info(video_ids) 
        st.success("Channel data collected successfully!")


    # Migrate to SQL if requested
    if st.button("Migrate to SQL"):
        Tables=tables(channel_id)
        st.success(Tables)

    show_table = st.radio("SELECT THE TABLE FOR VIEW", ("CHANNELS", "VIDEOS", "COMMENTS"))

    if show_table == "CHANNELS":
       show_channels_table(channel_id)
    elif show_table == "VIDEOS":
        show_videos_table(channel_id)

    elif show_table == "COMMENTS":
         show_comments_table(channel_id)

# %%
#sql connection 

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="Ayan@2202",
  database="project",
)
    
cursor = mydb.cursor()
question=st.selectbox("SELECT YOUR QUESTION",("1. All the videos and the channel name",
                                                "2. channels with most number of videos",
                                                "3. 10 most viewed videos and their channels",
                                                "4. No.of comments in each videos",
                                                "5. Videos with higest likes and their channel",
                                                "6. Total No.of likes of all videos",
                                                "7. Total No.of views of each channel",
                                                "8. Channels with videos published in the year of 2022",
                                                "9. average duration of all videos in each channel",
                                                "10. videos with highest number of comments"))

if question=="1. All the videos and the channel name":
    query1='''select Vid_Title as videos,Channel_Name as channelname from videos'''
    cursor.execute(query1)
    #mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)
    
elif question=="2. channels with most number of videos":
        query2='''select channel_name as channelname,video_count as no_videos from channels
                order by video_count  desc'''
        cursor.execute(query2)
        #mydb.commit()
        t2=cursor.fetchall()
        df2=pd.DataFrame(t2,columns=["channel name","No of videos"])
        st.write(df2)
        
elif question=="3. 10 most viewed videos and their channels":
        query3='''select Views as views,Channel_Name as channelname,Vid_Title as videotitle from videos
                    where views is not null order by Views desc limit 10'''
        cursor.execute(query3)
        #mydb.commit()
        t3=cursor.fetchall()
        df3=pd.DataFrame(t3,columns=["views","channel name","videotitle"])
        st.write(df3)
        
elif question=="4. No.of comments in each videos":
        query4='''select Comments as no_comments,Vid_Title as videotitle from videos where comments is not null'''
        cursor.execute(query4)
        #mydb.commit()
        t4=cursor.fetchall()
        df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
        st.write(df4)
        
elif question=="5. Videos with higest likes and their channel":
        query5='''select Vid_Title as videotitle,Channel_Name as channalname,likes as likecount
                        from videos where likes is not null order by likes desc'''
        cursor.execute(query5)
        #mydb.commit()
        t5=cursor.fetchall()
        df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
        st.write(df5)
        
elif question=="6. Total No.of likes of all videos":
        query6='''select likes as likecount,Vid_Title as videotitle from videos'''
        cursor.execute(query6)
        #mydb.commit()
        t6=cursor.fetchall()
        df6=pd.DataFrame(t6,columns=["likecount","videotitle"])
        st.write(df6)
        
elif question=="7. Total No.of views of each channel":
            query7='''select channel_name as channelname,view_Count as totalviews from channels'''
            cursor.execute(query7)
            #mydb.commit()
            t7=cursor.fetchall()
            df7=pd.DataFrame(t7,columns=["channel name","totalviews"])
            st.write(df7)
            
elif question=="8. Channels with videos published in the year of 2022":
        query8='''select Vid_Title as video_title, Vid_Published_Date as videorelease,Channel_Name as channel_name from videos
                    where extract(year from Vid_Published_Date)=2022'''
        cursor.execute(query8)
        #mydb.commit()
        t8=cursor.fetchall()
        df8=pd.DataFrame(t8,columns=["videotitle","Published_date","channel name"])
        st.write(df8)
elif question == "9. average duration of all videos in each channel":
        query9 = '''SELECT Channel_Name AS `channel name`, AVG(Vid_Duration) AS `averageduration` FROM videos GROUP BY Channel_Name'''
        cursor.execute(query9)
        # mydb.commit()
        t9 = cursor.fetchall()
        df9 = pd.DataFrame(t9, columns=["channel name", "averageduration"])
        
        T9 = []
        for index, row in df9.iterrows():
            channel_name = row["channel name"]
            average_duration = row["averageduration"]
            average_duration_str = str(average_duration)
            T9.append(dict(channeltitle=channel_name, avgduration=average_duration_str))
        df2 = pd.DataFrame(T9)
        st.write(df2)
        
elif question=="10. videos with highest number of comments":
        query10='''select Vid_Title as videotitle,Channel_Name as channelname,Comments as comments from videos where 
                   comments is not null order by Comments desc'''
        cursor.execute(query10)
        #mydb.commit()
        t10=cursor.fetchall()
        df10=pd.DataFrame(t10,columns=["videotitle","channel name","comments"])
        st.write(df10)
